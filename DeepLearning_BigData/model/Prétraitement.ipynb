# %% [markdown]
# # Exploration des données

# %% [markdown]
# ## 1. Chargement et aperçu des données

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, regexp_replace, lower, trim, when, length

# Initialiser la session Spark
spark = SparkSession.builder \
    .appName("Sentiment Analysis Preprocessing") \
    .getOrCreate()

# Définir les en-têtes manquants
headers = ["target", "ids", "date", "flag", "user", "text"]

# Charger le dataset sans en-têtes
file_path = "dataset/tweets.csv"  # Remplacez par le chemin de votre fichier CSV
df = spark.read.csv(file_path, sep=",", inferSchema=True).toDF(*headers)

# %%
# Étape 1 : Afficher un aperçu des données
print("Aperçu des données brutes :")
df.show(10, truncate=False)
# Out:
# Aperçu des données brutes :
# +------+----------+----------------------------+--------+---------------+-------------------------------------------------------------------------------------------------------------------+
# |target|ids       |date                        |flag    |user           |text                                                                                                               |
# +------+----------+----------------------------+--------+---------------+-------------------------------------------------------------------------------------------------------------------+
# |0     |1467810369|Mon Apr 06 22:19:45 PDT 2009|NO_QUERY|_TheSpecialOne_|@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D|
# |0     |1467810672|Mon Apr 06 22:19:49 PDT 2009|NO_QUERY|scotthamilton  |is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!    |
# |0     |1467810917|Mon Apr 06 22:19:53 PDT 2009|NO_QUERY|mattycus       |@Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds                          |
# |0     |1467811184|Mon Apr 06 22:19:57 PDT 2009|NO_QUERY|ElleCTF        |my whole body feels itchy and like its on fire                                                                     |
# |0     |1467811193|Mon Apr 06 22:19:57 PDT 2009|NO_QUERY|Karoli         |@nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.     |
# |0     |1467811372|Mon Apr 06 22:20:00 PDT 2009|NO_QUERY|joy_wolf       |@Kwesidei not the whole crew                                                                                       |
# |0     |1467811592|Mon Apr 06 22:20:03 PDT 2009|NO_QUERY|mybirch        |Need a hug                                                                                                         |
# |0     |1467811594|Mon Apr 06 22:20:03 PDT 2009|NO_QUERY|coZZ           |@LOLTrish hey  long time no see! Yes.. Rains a bit ,only a bit  LOL , I'm fine thanks , how's you ?                |
# |0     |1467811795|Mon Apr 06 22:20:05 PDT 2009|NO_QUERY|2Hood4Hollywood|@Tatiana_K nope they didn't have it                                                                                |
# |0     |1467812025|Mon Apr 06 22:20:09 PDT 2009|NO_QUERY|mimismo        |@twittera que me muera ?                                                                                           |
# +------+----------+----------------------------+--------+---------------+-------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ## 2. Dimensions du dataset

# %%
# Nombre de lignes et colonnes
num_rows = df.count()
num_cols = len(df.columns)

print(f"Le dataset contient {num_rows} lignes et {num_cols} colonnes.")
# Out:
# Le dataset contient 1600000 lignes et 6 colonnes.

# %%
# Vérifier le schéma des données
df.printSchema()

# Résumé statistique
df.describe().show()
# Out:
# root
#  |-- target: integer (nullable = true)
#  |-- ids: long (nullable = true)
#  |-- date: string (nullable = true)
#  |-- flag: string (nullable = true)
#  |-- user: string (nullable = true)
#  |-- text: string (nullable = true)
#
# +-------+-----------------+--------------------+--------------------+--------+--------------------+--------------------+
# |summary|           target|                 ids|                date|    flag|                user|                text|
# +-------+-----------------+--------------------+--------------------+--------+--------------------+--------------------+
# |  count|          1600000|             1600000|             1600000| 1600000|             1600000|             1600000|
# |   mean|              2.0|1.9988175522956276E9|                NULL|    NULL| 4.325887521835714E9|                NULL|
# | stddev|2.000000625000293| 1.935760736226641E8|                NULL|    NULL|5.162733218454889E10|                NULL|
# |    min|                0|          1467810369|Fri Apr 17 20:30:...|NO_QUERY|        000catnap000|                 ...|
# |    max|                4|          2329205794|Wed May 27 07:27:...|NO_QUERY|          zzzzeus111|�����ߧ�ǿ�����ж�؜�...|
# +-------+-----------------+--------------------+--------------------+--------+--------------------+--------------------+

# %% [markdown]
# ## 3. Distribution des sentiments (cibles)

# %%
# Compter le nombre de tweets par classe de polarité
df.groupBy("target").count().show()
# Out:
# +------+------+
# |target| count|
# +------+------+
# |     0|800000|
# |     4|800000|
# +------+------+

# %%
# Nombre d'utilisateurs uniques
df.select("user").distinct().count()

# Longueur moyenne des tweets
from pyspark.sql.functions import length
df = df.withColumn("text_length", length("text"))
df.select("text_length").describe().show()
# Out:
# +-------+-----------------+
# |summary|      text_length|
# +-------+-----------------+
# |  count|          1600000|
# |   mean|     74.041759375|
# | stddev|36.38799215515103|
# |    min|                6|
# |    max|              359|
# +-------+-----------------+

# %% [markdown]
# # Nettoyage des données

# %% [markdown]
# ## 1. Suppression des colonnes inutiles

# %%
columns_to_drop = ["ids", "date", "flag", "user"]
df = df.drop(*columns_to_drop)

# %%
# Vérifier les données après suppression
df.show(5)
# Out:
# +------+--------------------+-----------+
# |target|                text|text_length|
# +------+--------------------+-----------+
# |     0|@switchfoot http:...|        115|
# |     0|is upset that he ...|        111|
# |     0|@Kenichan I dived...|         89|
# |     0|my whole body fee...|         47|
# |     0|@nationwideclass ...|        111|
# +------+--------------------+-----------+
# only showing top 5 rows

# %% [markdown]
# ## 2. Nettoyage des textes

# %% [markdown]
# ### 2.1 Supprimer les URLs

# %%
df = df.withColumn("text", regexp_replace(col("text"), r"http\S+", ""))

# %% [markdown]
# ### 2.2 Supprimer les mentions Twitter (@username)

# %%
df = df.withColumn("text", regexp_replace(col("text"), r"@\w+", ""))

# %% [markdown]
# ### 2.3 Supprimer les hashtags (#hashtag)

# %%
df = df.withColumn("text", regexp_replace(col("text"), r"#\w+", ""))

# %% [markdown]
# ### 2.4  Supprimer les caractères spéciaux (émoticônes, ponctuations, etc.)

# %%
df = df.withColumn("text", regexp_replace(col("text"), r"[^a-zA-Z\s]", ""))

# %% [markdown]
# ### 2.5 Convertir en minuscules

# %%
df = df.withColumn("text", lower(col("text")))

# %% [markdown]
# ### 2.6 Supprimer les espaces multiples

# %%
df = df.withColumn("text", regexp_replace(col("text"), r"\s+", " "))

# %% [markdown]
# ### 2.7 Supprimer les espaces de début et de fin

# %%
df = df.withColumn("text", trim(col("text")))

# %% [markdown]
# ### 2.8 Supprimer les textes vides ou très courts (moins de 3 caractères)

# %%
df = df.withColumn("text_length", length(col("text")))
df = df.filter(col("text_length") > 3).drop("text_length")

# %% [markdown]
# ### 2.9 Gérer les valeurs manquantes

# %%
df = df.withColumn("text", when(col("text").isNull() | (col("text") == ""), "texte_vide").otherwise(col("text")))

# %%
# Affichage de la dataset aprés la suppresion 
df.show(5, truncate=False)
# Out:
# +------+--------------------------------------------------------------------------------------------------------+
# |target|text                                                                                                    |
# +------+--------------------------------------------------------------------------------------------------------+
# |0     |awww thats a bummer you shoulda got david carr of third day to do it d                                  |
# |0     |is upset that he cant update his facebook by texting it and might cry as a result school today also blah|
# |0     |i dived many times for the ball managed to save the rest go out of bounds                               |
# |0     |my whole body feels itchy and like its on fire                                                          |
# |0     |no its not behaving at all im mad why am i here because i cant see you all over there                   |
# +------+--------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# ## 3. Tokenisation :

# %% [markdown]
# ### 3.1 Tokenisation Simple

# %%
from pyspark.ml.feature import Tokenizer

# Tokenisation simple
tokenizer = Tokenizer(inputCol="text", outputCol="tokens")
df = tokenizer.transform(df)

# Afficher les tokens
df.select("text", "tokens").show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+
# |text                                                                                                    |tokens                                                                                                                        |
# +--------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+
# |awww thats a bummer you shoulda got david carr of third day to do it d                                  |[awww, thats, a, bummer, you, shoulda, got, david, carr, of, third, day, to, do, it, d]                                       |
# |is upset that he cant update his facebook by texting it and might cry as a result school today also blah|[is, upset, that, he, cant, update, his, facebook, by, texting, it, and, might, cry, as, a, result, school, today, also, blah]|
# |i dived many times for the ball managed to save the rest go out of bounds                               |[i, dived, many, times, for, the, ball, managed, to, save, the, rest, go, out, of, bounds]                                    |
# |my whole body feels itchy and like its on fire                                                          |[my, whole, body, feels, itchy, and, like, its, on, fire]                                                                     |
# |no its not behaving at all im mad why am i here because i cant see you all over there                   |[no, its, not, behaving, at, all, im, mad, why, am, i, here, because, i, cant, see, you, all, over, there]                    |
# |not the whole crew                                                                                      |[not, the, whole, crew]                                                                                                       |
# |need a hug                                                                                              |[need, a, hug]                                                                                                                |
# |hey long time no see yes rains a bit only a bit lol im fine thanks hows you                             |[hey, long, time, no, see, yes, rains, a, bit, only, a, bit, lol, im, fine, thanks, hows, you]                                |
# |nope they didnt have it                                                                                 |[nope, they, didnt, have, it]                                                                                                 |
# |que me muera                                                                                            |[que, me, muera]                                                                                                              |
# |spring break in plain city its snowing                                                                  |[spring, break, in, plain, city, its, snowing]                                                                                |
# |i just repierced my ears                                                                                |[i, just, repierced, my, ears]                                                                                                |
# |i couldnt bear to watch it and i thought the ua loss was embarrassing                                   |[i, couldnt, bear, to, watch, it, and, i, thought, the, ua, loss, was, embarrassing]                                          |
# |it it counts idk why i did either you never talk to me anymore                                          |[it, it, counts, idk, why, i, did, either, you, never, talk, to, me, anymore]                                                 |
# |i wouldve been the first but i didnt have a gun not really though zac snyders just a doucheclown        |[i, wouldve, been, the, first, but, i, didnt, have, a, gun, not, really, though, zac, snyders, just, a, doucheclown]          |
# |i wish i got to watch it with you i miss you and how was the premiere                                   |[i, wish, i, got, to, watch, it, with, you, i, miss, you, and, how, was, the, premiere]                                       |
# |hollis death scene will hurt me severely to watch on film wry is directors cut not out now              |[hollis, death, scene, will, hurt, me, severely, to, watch, on, film, wry, is, directors, cut, not, out, now]                 |
# |about to file taxes                                                                                     |[about, to, file, taxes]                                                                                                      |
# |ahh ive always wanted to see rent love the soundtrack                                                   |[ahh, ive, always, wanted, to, see, rent, love, the, soundtrack]                                                              |
# |oh dear were you drinking out of the forgotten table drinks                                             |[oh, dear, were, you, drinking, out, of, the, forgotten, table, drinks]                                                       |
# +--------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## 3.2 Suppression des Mots Vides (Stop Words)

# %%
from pyspark.ml.feature import StopWordsRemover

# Suppression des mots vides
remover = StopWordsRemover(inputCol="tokens", outputCol="filtered_tokens")
df = remover.transform(df)

# Afficher les tokens filtrés
df.select("tokens", "filtered_tokens").show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+
# |tokens                                                                                                                        |filtered_tokens                                                                        |
# +------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+
# |[awww, thats, a, bummer, you, shoulda, got, david, carr, of, third, day, to, do, it, d]                                       |[awww, thats, bummer, shoulda, got, david, carr, third, day, d]                        |
# |[is, upset, that, he, cant, update, his, facebook, by, texting, it, and, might, cry, as, a, result, school, today, also, blah]|[upset, cant, update, facebook, texting, might, cry, result, school, today, also, blah]|
# |[i, dived, many, times, for, the, ball, managed, to, save, the, rest, go, out, of, bounds]                                    |[dived, many, times, ball, managed, save, rest, go, bounds]                            |
# |[my, whole, body, feels, itchy, and, like, its, on, fire]                                                                     |[whole, body, feels, itchy, like, fire]                                                |
# |[no, its, not, behaving, at, all, im, mad, why, am, i, here, because, i, cant, see, you, all, over, there]                    |[behaving, im, mad, cant, see]                                                         |
# |[not, the, whole, crew]                                                                                                       |[whole, crew]                                                                          |
# |[need, a, hug]                                                                                                                |[need, hug]                                                                            |
# |[hey, long, time, no, see, yes, rains, a, bit, only, a, bit, lol, im, fine, thanks, hows, you]                                |[hey, long, time, see, yes, rains, bit, bit, lol, im, fine, thanks, hows]              |
# |[nope, they, didnt, have, it]                                                                                                 |[nope, didnt]                                                                          |
# |[que, me, muera]                                                                                                              |[que, muera]                                                                           |
# |[spring, break, in, plain, city, its, snowing]                                                                                |[spring, break, plain, city, snowing]                                                  |
# |[i, just, repierced, my, ears]                                                                                                |[repierced, ears]                                                                      |
# |[i, couldnt, bear, to, watch, it, and, i, thought, the, ua, loss, was, embarrassing]                                          |[couldnt, bear, watch, thought, ua, loss, embarrassing]                                |
# |[it, it, counts, idk, why, i, did, either, you, never, talk, to, me, anymore]                                                 |[counts, idk, either, never, talk, anymore]                                            |
# |[i, wouldve, been, the, first, but, i, didnt, have, a, gun, not, really, though, zac, snyders, just, a, doucheclown]          |[wouldve, first, didnt, gun, really, though, zac, snyders, doucheclown]                |
# |[i, wish, i, got, to, watch, it, with, you, i, miss, you, and, how, was, the, premiere]                                       |[wish, got, watch, miss, premiere]                                                     |
# |[hollis, death, scene, will, hurt, me, severely, to, watch, on, film, wry, is, directors, cut, not, out, now]                 |[hollis, death, scene, hurt, severely, watch, film, wry, directors, cut]               |
# |[about, to, file, taxes]                                                                                                      |[file, taxes]                                                                          |
# |[ahh, ive, always, wanted, to, see, rent, love, the, soundtrack]                                                              |[ahh, ive, always, wanted, see, rent, love, soundtrack]                                |
# |[oh, dear, were, you, drinking, out, of, the, forgotten, table, drinks]                                                       |[oh, dear, drinking, forgotten, table, drinks]                                         |
# +------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ### 3.3 Extraction des n-grammes

# %%
from pyspark.ml.feature import NGram

# Générer des bigrammes (n=2)
ngram = NGram(n=2, inputCol="filtered_tokens", outputCol="bigrams")
df = ngram.transform(df)

# Afficher les bigrammes
df.select("filtered_tokens", "bigrams").show(truncate=False)

# Générer des trigrammes (n=3)
ngram3 = NGram(n=3, inputCol="filtered_tokens", outputCol="trigrams")
df = ngram3.transform(df)

# Afficher les trigrammes
df.select("filtered_tokens", "trigrams").show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------+
# |filtered_tokens                                                                        |bigrams                                                                                                                                               |
# +---------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[awww, thats, bummer, shoulda, got, david, carr, third, day, d]                        |[awww thats, thats bummer, bummer shoulda, shoulda got, got david, david carr, carr third, third day, day d]                                          |
# |[upset, cant, update, facebook, texting, might, cry, result, school, today, also, blah]|[upset cant, cant update, update facebook, facebook texting, texting might, might cry, cry result, result school, school today, today also, also blah]|
# |[dived, many, times, ball, managed, save, rest, go, bounds]                            |[dived many, many times, times ball, ball managed, managed save, save rest, rest go, go bounds]                                                       |
# |[whole, body, feels, itchy, like, fire]                                                |[whole body, body feels, feels itchy, itchy like, like fire]                                                                                          |
# |[behaving, im, mad, cant, see]                                                         |[behaving im, im mad, mad cant, cant see]                                                                                                             |
# |[whole, crew]                                                                          |[whole crew]                                                                                                                                          |
# |[need, hug]                                                                            |[need hug]                                                                                                                                            |
# |[hey, long, time, see, yes, rains, bit, bit, lol, im, fine, thanks, hows]              |[hey long, long time, time see, see yes, yes rains, rains bit, bit bit, bit lol, lol im, im fine, fine thanks, thanks hows]                           |
# |[nope, didnt]                                                                          |[nope didnt]                                                                                                                                          |
# |[que, muera]                                                                           |[que muera]                                                                                                                                           |
# |[spring, break, plain, city, snowing]                                                  |[spring break, break plain, plain city, city snowing]                                                                                                 |
# |[repierced, ears]                                                                      |[repierced ears]                                                                                                                                      |
# |[couldnt, bear, watch, thought, ua, loss, embarrassing]                                |[couldnt bear, bear watch, watch thought, thought ua, ua loss, loss embarrassing]                                                                     |
# |[counts, idk, either, never, talk, anymore]                                            |[counts idk, idk either, either never, never talk, talk anymore]                                                                                      |
# |[wouldve, first, didnt, gun, really, though, zac, snyders, doucheclown]                |[wouldve first, first didnt, didnt gun, gun really, really though, though zac, zac snyders, snyders doucheclown]                                      |
# |[wish, got, watch, miss, premiere]                                                     |[wish got, got watch, watch miss, miss premiere]                                                                                                      |
# |[hollis, death, scene, hurt, severely, watch, film, wry, directors, cut]               |[hollis death, death scene, scene hurt, hurt severely, severely watch, watch film, film wry, wry directors, directors cut]                            |
# |[file, taxes]                                                                          |[file taxes]                                                                                                                                          |
# |[ahh, ive, always, wanted, see, rent, love, soundtrack]                                |[ahh ive, ive always, always wanted, wanted see, see rent, rent love, love soundtrack]                                                                |
# |[oh, dear, drinking, forgotten, table, drinks]                                         |[oh dear, dear drinking, drinking forgotten, forgotten table, table drinks]                                                                           |
# +---------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# +---------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |filtered_tokens                                                                        |trigrams                                                                                                                                                                                                   |
# +---------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[awww, thats, bummer, shoulda, got, david, carr, third, day, d]                        |[awww thats bummer, thats bummer shoulda, bummer shoulda got, shoulda got david, got david carr, david carr third, carr third day, third day d]                                                            |
# |[upset, cant, update, facebook, texting, might, cry, result, school, today, also, blah]|[upset cant update, cant update facebook, update facebook texting, facebook texting might, texting might cry, might cry result, cry result school, result school today, school today also, today also blah]|
# |[dived, many, times, ball, managed, save, rest, go, bounds]                            |[dived many times, many times ball, times ball managed, ball managed save, managed save rest, save rest go, rest go bounds]                                                                                |
# |[whole, body, feels, itchy, like, fire]                                                |[whole body feels, body feels itchy, feels itchy like, itchy like fire]                                                                                                                                    |
# |[behaving, im, mad, cant, see]                                                         |[behaving im mad, im mad cant, mad cant see]                                                                                                                                                               |
# |[whole, crew]                                                                          |[]                                                                                                                                                                                                         |
# |[need, hug]                                                                            |[]                                                                                                                                                                                                         |
# |[hey, long, time, see, yes, rains, bit, bit, lol, im, fine, thanks, hows]              |[hey long time, long time see, time see yes, see yes rains, yes rains bit, rains bit bit, bit bit lol, bit lol im, lol im fine, im fine thanks, fine thanks hows]                                          |
# |[nope, didnt]                                                                          |[]                                                                                                                                                                                                         |
# |[que, muera]                                                                           |[]                                                                                                                                                                                                         |
# |[spring, break, plain, city, snowing]                                                  |[spring break plain, break plain city, plain city snowing]                                                                                                                                                 |
# |[repierced, ears]                                                                      |[]                                                                                                                                                                                                         |
# |[couldnt, bear, watch, thought, ua, loss, embarrassing]                                |[couldnt bear watch, bear watch thought, watch thought ua, thought ua loss, ua loss embarrassing]                                                                                                          |
# |[counts, idk, either, never, talk, anymore]                                            |[counts idk either, idk either never, either never talk, never talk anymore]                                                                                                                               |
# |[wouldve, first, didnt, gun, really, though, zac, snyders, doucheclown]                |[wouldve first didnt, first didnt gun, didnt gun really, gun really though, really though zac, though zac snyders, zac snyders doucheclown]                                                                |
# |[wish, got, watch, miss, premiere]                                                     |[wish got watch, got watch miss, watch miss premiere]                                                                                                                                                      |
# |[hollis, death, scene, hurt, severely, watch, film, wry, directors, cut]               |[hollis death scene, death scene hurt, scene hurt severely, hurt severely watch, severely watch film, watch film wry, film wry directors, wry directors cut]                                               |
# |[file, taxes]                                                                          |[]                                                                                                                                                                                                         |
# |[ahh, ive, always, wanted, see, rent, love, soundtrack]                                |[ahh ive always, ive always wanted, always wanted see, wanted see rent, see rent love, rent love soundtrack]                                                                                               |
# |[oh, dear, drinking, forgotten, table, drinks]                                         |[oh dear drinking, dear drinking forgotten, drinking forgotten table, forgotten table drinks]                                                                                                              |
# +---------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## 4. Vectorisation des Textes avec Word2Vec

# %%
from pyspark.ml.feature import Word2Vec

# Appliquer le modèle Word2Vec
word2Vec = Word2Vec(vectorSize=100, minCount=5, inputCol="filtered_tokens", outputCol="word_embeddings")
model = word2Vec.fit(df)
df = model.transform(df)

# Afficher un aperçu des colonnes après Word2Vec
df.select("target", "text", "word_embeddings").show(5, truncate=False)
# Out:
# +------+--------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |target|text                                                                                                    |word_embeddings                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
#
04201529175043106,0.006020605564117432,0.1369511775672436,-0.1302836835384369,-0.037052846327424054,-0.0779310703277588,0.0048677708953619005,-0.06805839389562607,0.12932962365448475,0.09026345610618591,-0.05831732589285821,0.05907904878258705,-0.06325384173542262,0.04166569816879928,0.04670567959547043,0.012876208126544953,-0.03603038750588894,0.03545960634946823,-0.030363422073423865,0.08381471950560809,-0.029647921770811082,-0.14238084703683854,0.09561128914356232,0.13805006630718708,-0.11191544383764268,0.0017635539174079896,-0.11568967550992966,-0.10974943488836289,0.006350308656692505,-0.09547499371692539,0.029557105898857117,0.04965616436675191,0.08899711668491364,0.04378338573733345,0.042700393497943884,0.06985842771828175,-0.21909236162900925,-0.2205170437693596,-0.1799227874726057,-0.014634622063022108,0.06858731616521255,0.02199913188815117,-0.08632082510739565]                |
# +------+--------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
# Sélectionner uniquement les colonnes 'target' et 'text' nettoyé
df_clean = df.select("target", "text")

# Afficher un aperçu des données nettoyées
df_clean.show(5, truncate=False)
# Out:
# +------+--------------------------------------------------------------------------------------------------------+
# |target|text                                                                                                    |
# +------+--------------------------------------------------------------------------------------------------------+
# |0     |awww thats a bummer you shoulda got david carr of third day to do it d                                  |
# |0     |is upset that he cant update his facebook by texting it and might cry as a result school today also blah|
# |0     |i dived many times for the ball managed to save the rest go out of bounds                               |
# |0     |my whole body feels itchy and like its on fire                                                          |
# |0     |no its not behaving at all im mad why am i here because i cant see you all over there                   |
# +------+--------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import when

# Filtrer les tweets avec target = 0 (négatif) et target = 4 (positif)
df_target_0 = df_clean.filter(col("target") == 0)
df_target_4 = df_clean.filter(col("target") == 4)

# Limiter à 100000 lignes pour chaque classe
df_target_0_sampled = df_target_0.limit(50000)
df_target_4_sampled = df_target_4.limit(50000)

# Combiner les deux échantillons
df_balanced = df_target_0_sampled.union(df_target_4_sampled)

# Convertir target 4 en 1 (positif)
df_balanced = df_balanced.withColumn("target", when(col("target") == 4, 1).otherwise(col("target")))

# Vérifier le nombre de lignes après équilibrage
print(f"Nombre total de lignes après équilibrage : {df_balanced.count()}")
# Out:
# Nombre total de lignes après équilibrage : 100000

# %%
# Sauvegarder le dataset équilibré sous forme d'un seul fichier CSV
output_balanced_path = "cleaned_dataset.csv"
df_balanced.coalesce(1).write.mode("overwrite").option("header", "true").csv(output_balanced_path)

# Afficher un message de confirmation
print(f"Le dataset équilibré a été sauvegardé sous {output_balanced_path}.")
# Out:
# Le dataset équilibré a été sauvegardé sous balanced_cleaned_tweets.csv.

# %%
import pandas as pd

# Charger le fichier CSV
df = pd.read_csv("cleaned_dataset.csv")

# Séparer les lignes où target == 0 et target == 1
df_target_0 = df[df['target'] == 0]
df_target_1 = df[df['target'] == 1]

# Supprimer les 50 000 premières lignes de chaque groupe
df_target_0 = df_target_0.iloc[50000:]
df_target_1 = df_target_1.iloc[50000:]

# Combiner les deux groupes modifiés
df_modified = pd.concat([df_target_0, df_target_1])

# Sauvegarder le fichier modifié sous format CSV
df_modified.to_csv("testing.csv", index=False)
